# %%
import pandas as pd

# %%
# считаем описание данных
df = pd.read_csv('02_otp_desc.csv', sep=';').loc[:,'ПОЛЕ':'ОПИСАНИЕ']

# %%
df
# Out:
#                           ПОЛЕ  \
# 0                 AGREEMENT_RK
# 1                       TARGET
# 2                          AGE
# 3            SOCSTATUS_WORK_FL
# 4            SOCSTATUS_PENS_FL
# 5                       GENDER
# 6                  CHILD_TOTAL
# 7                   DEPENDANTS
# 8                    EDUCATION
# 9               MARITAL_STATUS
# 10                GEN_INDUSTRY
# 11                   GEN_TITLE
# 12                ORG_TP_STATE
# 13             ORG_TP_FCAPITAL
# 14                     JOB_DIR
# 15               FAMILY_INCOME
# 16             PERSONAL_INCOME
# 17        REG_ADDRESS_PROVINCE
# 18       FACT_ADDRESS_PROVINCE
# 19     POSTAL_ADDRESS_PROVINCE
# 20                 TP_PROVINCE
# 21                   REGION_NM
# 22                 REG_FACT_FL
# 23                FACT_POST_FL
# 24                 REG_POST_FL
# 25            REG_FACT_POST_FL
# 26         REG_FACT_POST_TP_FL
# 27              FL_PRESENCE_FL
# 28                    OWN_AUTO
# 29                 AUTO_RUS_FL
# 30              HS_PRESENCE_FL
# 31             COT_PRESENCE_FL
# 32             GAR_PRESENCE_FL
# 33            LAND_PRESENCE_FL
# 34                      CREDIT
# 35                        TERM
# 36                 FST_PAYMENT
# 37              DL_DOCUMENT_FL
# 38             GPF_DOCUMENT_FL
# 39            FACT_LIVING_TERM
# 40                   WORK_TIME
# 41               FACT_PHONE_FL
# 42                REG_PHONE_FL
# 43                GEN_PHONE_FL
# 44              LOAN_NUM_TOTAL
# 45             LOAN_NUM_CLOSED
# 46               LOAN_NUM_PAYM
# 47                LOAN_DLQ_NUM
# 48                LOAN_MAX_DLQ
# 49            LOAN_AVG_DLQ_AMT
# 50            LOAN_MAX_DLQ_AMT
# 51  PREVIOUS_CARD_NUM_UTILIZED
#
#                                              ОПИСАНИЕ
# 0          уникальный идентификатор объекта в выборке
# 1   целевая переменная:отклик на маркетинговую кам...
# 2                                     возраст клиента
# 3   социальный статус клиента относительно работы ...
# 4   социальный статус клиента относительно пенсии ...
# 5                                         пол клиента
# 6                            количество детей клиента
# 7                       количество иждивенцев клиента
# 8                                         образование
# 9                                  семейное положение
# 10                             отрасль работы клиента
# 11                                          должность
# 12                       форма собственности компании
# 13                  отношение к иностранному капиталу
# 14          направление деятельности в нутри компании
# 15               семейный доход (несколько категорий)
# 16                    личный доход клиента (в рублях)
# 17                        область регистрации клиента
# 18            область фактического пребывания клиента
# 19                             почтовый адрес область
# 20  область торговой точки, где клиент брал послед...
# 21                                          регион РФ
# 22  адрес регистрации и адрес фактического пребыва...
# 23  адрес фактического пребывания клиента и его по...
# 24  адрес регистрации клиента и его почтовый адрес...
# 25  почтовый, фактический и адрес регистрации совп...
# 26  область регистрации, фактического пребывания, ...
# 27  наличие в собственности квартиры (1 - есть, 0 ...
# 28                кол-во автомобилей в собственности
# 29  наличие в собственности автомобиля российского...
# 30  наличие в собственности загородного дома (1 - ...
# 31  наличие в собственности котеджа (1 - есть, 0 -...
# 32  наличие в собственности гаража (1 - есть, 0 - ...
# 33  наличие в собственности земельного участка (1 ...
# 34        сумма последнего кредита клиента (в рублях)
# 35                                       срок кредита
# 36                    первоначальный взнос (в рублях)
# 37  в анкете клиент указал водительское удостовере...
# 38  в анкете клиен указал ГПФ (1 - указал, 0 - не ...
# 39  количество месяцев проживания по месту фактиче...
# 40          время работы на текущем месте (в месяцах)
# 41  наличие в заявке телефона по фактическому мест...
# 42     наличие в заявке телефона по месту регистрации
# 43                 наличие в заявке рабочего телефона
# 44                            количество ссуд клиента
# 45                 количество погашенных ссуд клиента
# 46         количество платежей, которые сделал клиент
# 47          количество просрочек, допущенных клиентом
# 48  номер максимальной просрочки, допущенной клиентом
# 49                 средняя сумма просрочки (в рублях)
# 50            максимальная сумма просрочки (в рублях)
# 51  количество уже утилизированных карт ( если пус...

# %%
# считаем все-все данные

# %%
train = pd.read_csv('02_otp_train.csv', sep=';')

# %%
train.shape
# Out:
# (15223, 52)

# %%
test = pd.read_csv('02_otp_test.csv', sep=';')

# %%
test.shape
# Out:
# (14910, 51)

# %%
# отделим таргет от TRAIN-а

# %%
y = train['TARGET']

# %%
train = train.drop('TARGET', axis=1)

# %%
# соеденим train и test

# %%
all_data = pd.concat([train, test])

# %%
# необходимо удалить индекс, 
# у нас есть 0-строка в train и 0-строка в test (и так далее 1,2,3,4)
# если мы просто объеденим - у нас сохранятся индексы
# мы же просто уберем индекс и автоматически создастся новый индекс, сквозной и уникальный
all_data = all_data.reset_index(drop=True)

# %%
# посмотрим типы данных и их заполняемость

# %%
all_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30133 entries, 0 to 30132
# Data columns (total 51 columns):
# AGREEMENT_RK                  30133 non-null int64
# AGE                           30133 non-null int64
# SOCSTATUS_WORK_FL             30133 non-null int64
# SOCSTATUS_PENS_FL             30133 non-null int64
# GENDER                        30133 non-null int64
# CHILD_TOTAL                   30133 non-null int64
# DEPENDANTS                    30133 non-null int64
# EDUCATION                     30133 non-null object
# MARITAL_STATUS                30133 non-null object
# GEN_INDUSTRY                  27420 non-null object
# GEN_TITLE                     27420 non-null object
# ORG_TP_STATE                  27420 non-null object
# ORG_TP_FCAPITAL               27425 non-null object
# JOB_DIR                       27420 non-null object
# FAMILY_INCOME                 30133 non-null object
# PERSONAL_INCOME               30133 non-null object
# REG_ADDRESS_PROVINCE          30133 non-null object
# FACT_ADDRESS_PROVINCE         30133 non-null object
# POSTAL_ADDRESS_PROVINCE       30133 non-null object
# TP_PROVINCE                   29543 non-null object
# REGION_NM                     30131 non-null object
# REG_FACT_FL                   30133 non-null int64
# FACT_POST_FL                  30133 non-null int64
# REG_POST_FL                   30133 non-null int64
# REG_FACT_POST_FL              30133 non-null int64
# REG_FACT_POST_TP_FL           30133 non-null int64
# FL_PRESENCE_FL                30133 non-null int64
# OWN_AUTO                      30133 non-null int64
# AUTO_RUS_FL                   30133 non-null int64
# HS_PRESENCE_FL                30133 non-null int64
# COT_PRESENCE_FL               30133 non-null int64
# GAR_PRESENCE_FL               30133 non-null int64
# LAND_PRESENCE_FL              30133 non-null int64
# CREDIT                        30133 non-null object
# TERM                          30133 non-null int64
# FST_PAYMENT                   30133 non-null object
# DL_DOCUMENT_FL                30133 non-null int64
# GPF_DOCUMENT_FL               30133 non-null int64
# FACT_LIVING_TERM              30133 non-null int64
# WORK_TIME                     27416 non-null float64
# FACT_PHONE_FL                 30133 non-null int64
# REG_PHONE_FL                  30133 non-null int64
# GEN_PHONE_FL                  30133 non-null int64
# LOAN_NUM_TOTAL                30133 non-null int64
# LOAN_NUM_CLOSED               30133 non-null int64
# LOAN_NUM_PAYM                 30133 non-null int64
# LOAN_DLQ_NUM                  30133 non-null int64
# LOAN_MAX_DLQ                  30133 non-null int64
# LOAN_AVG_DLQ_AMT              30133 non-null object
# LOAN_MAX_DLQ_AMT              30133 non-null object
# PREVIOUS_CARD_NUM_UTILIZED    600 non-null float64
# dtypes: float64(2), int64(31), object(18)
# memory usage: 11.7+ MB

# %%
# Видим, что часть данных - object, скорее всего стоки.
# Давайте выведем эти значения для каждого столбца

# %%
for i in all_data.columns: # перебираем все столбцы
    if str(all_data[i].dtype) == 'object': # если тип столбца - object
        print(i) # выводим название столбца
        print(set(all_data[i])) # выводим все его значения (но делаем set - чтоб значения не повторялись)
        print() # выводим пустую строку
# Out:
# EDUCATION
# {'Ученая степень', 'Неполное среднее', 'Неоконченное высшее', 'Высшее', 'Среднее специальное', 'Два и более высших образования', 'Среднее'}
#
# MARITAL_STATUS
# {'Не состоял в браке', 'Состою в браке', 'Гражданский брак', 'Разведен(а)', 'Вдовец/Вдова'}
#
# GEN_INDUSTRY
# {nan, 'Сельское хозяйство', 'Туризм', 'Государственная служба', 'Энергетика', 'Нефтегазовая промышленность', 'Юридические услуги/нотариальные услуги', 'Маркетинг', 'Недвижимость', 'Строительство', 'Коммунальное хоз-во/Дорожные службы', 'Металлургия/Промышленность/Машиностроение', 'Химия/Парфюмерия/Фармацевтика', 'Страхование', 'Информационные технологии', 'Ресторанный бизнес/Общественное питание', 'Управляющая компания', 'Логистика', 'СМИ/Реклама/PR-агенства', 'Подбор персонала', 'ЧОП/Детективная д-ть', 'Образование', 'Торговля', 'Здравоохранение', 'Наука', 'Банк/Финансы', 'Салоны красоты и здоровья', 'Сборочные производства', 'Развлечения/Искусство', 'Другие сферы', 'Информационные услуги', 'Транспорт'}
#
# GEN_TITLE
# {'Руководитель высшего звена', nan, 'Индивидуальный предприниматель', 'Рабочий', 'Специалист', 'Высококвалифиц. специалист', 'Руководитель низшего звена', 'Служащий', 'Работник сферы услуг', 'Военнослужащий по контракту', 'Руководитель среднего звена', 'Другое', 'Партнер'}
#
# ORG_TP_STATE
# {nan, 'Некоммерческая организация', 'Индивидуальный предприниматель', 'Частная компания', 'Государственная комп./учреж.', 'Частная ком. с инос. капиталом'}
#
# ORG_TP_FCAPITAL
# {nan, 'Без участия', 'С участием'}
#
# JOB_DIR
#
# REG_ADDRESS_PROVINCE
# {'Ленинградская область', 'Владимирская область', 'Москва', 'Воронежская область', 'Ярославская область', 'Архангельская область', 'Томская область', 'Нижегородская область', 'Удмуртия', 'Сахалинская область', 'Хакасия', 'Новосибирская область', 'Ростовская область', 'Коми-Пермяцкий АО', 'Псковская область', 'Якутия', 'Астраханская область', 'Северная Осетия', 'Ханты-Мансийский АО', 'Волгоградская область', 'Алтайский край', 'Бурятия', 'Омская область', 'Санкт-Петербург', 'Башкирия', 'Камчатская область', 'Свердловская область', 'Калужская область', 'Самарская область', 'Тульская область', 'Тверская область', 'Новгородская область', 'Дагестан', 'Амурская область', 'Ульяновская область', 'Агинский Бурятский АО', 'Вологодская область', 'Карачаево-Черкесия', 'Ямало-Ненецкий АО', 'Кемеровская область', 'Челябинская область', 'Ставропольский край', 'Хабаровский край', 'Мурманская область', 'Липецкая область', 'Саратовская область', 'Адыгея', 'Ивановская область', 'Читинская область', 'Пензенская область', 'Татарстан', 'Карелия', 'Рязанская область', 'Московская область', 'Марийская республика', 'Красноярский край', 'Орловская область', 'Пермская область', 'Еврейская АО', 'Оренбургская область', 'Коми', 'Белгородская область', 'Кировская область', 'Смоленская область', 'Усть-Ордынский Бурятский АО', 'Тамбовская область', 'Курская область', 'Брянская область', 'Калмыкия', 'Иркутская область', 'Тюменская область', 'Горный Алтай', 'Магаданская область', 'Костромская область', 'Чувашия', 'Приморский край', 'Кабардино-Балкария', 'Курганская область', 'Краснодарский край', 'Калининградская область', 'Эвенкийский АО', 'Мордовская республика'}
#
# FACT_ADDRESS_PROVINCE
# {'Ленинградская область', 'Владимирская область', 'Москва', 'Воронежская область', 'Ярославская область', 'Архангельская область', 'Томская область', 'Нижегородская область', 'Удмуртия', 'Сахалинская область', 'Хакасия', 'Новосибирская область', 'Ростовская область', 'Коми-Пермяцкий АО', 'Псковская область', 'Якутия', 'Астраханская область', 'Северная Осетия', 'Ханты-Мансийский АО', 'Волгоградская область', 'Алтайский край', 'Бурятия', 'Омская область', 'Санкт-Петербург', 'Башкирия', 'Камчатская область', 'Свердловская область', 'Калужская область', 'Самарская область', 'Тульская область', 'Тверская область', 'Новгородская область', 'Дагестан', 'Амурская область', 'Ульяновская область', 'Агинский Бурятский АО', 'Вологодская область', 'Карачаево-Черкесия', 'Ямало-Ненецкий АО', 'Кемеровская область', 'Челябинская область', 'Ставропольский край', 'Хабаровский край', 'Мурманская область', 'Липецкая область', 'Саратовская область', 'Адыгея', 'Ивановская область', 'Читинская область', 'Пензенская область', 'Татарстан', 'Карелия', 'Московская область', 'Рязанская область', 'Марийская республика', 'Чечня', 'Красноярский край', 'Орловская область', 'Пермская область', 'Еврейская АО', 'Оренбургская область', 'Коми', 'Белгородская область', 'Кировская область', 'Смоленская область', 'Усть-Ордынский Бурятский АО', 'Тамбовская область', 'Курская область', 'Брянская область', 'Калмыкия', 'Иркутская область', 'Тюменская область', 'Горный Алтай', 'Магаданская область', 'Костромская область', 'Чувашия', 'Приморский край', 'Кабардино-Балкария', 'Курганская область', 'Краснодарский край', 'Калининградская область', 'Эвенкийский АО', 'Мордовская республика'}
#
# POSTAL_ADDRESS_PROVINCE
# {'Ленинградская область', 'Владимирская область', 'Москва', 'Воронежская область', 'Ярославская область', 'Архангельская область', 'Томская область', 'Нижегородская область', 'Удмуртия', 'Сахалинская область', 'Хакасия', 'Новосибирская область', 'Ростовская область', 'Коми-Пермяцкий АО', 'Псковская область', 'Якутия', 'Астраханская область', 'Северная Осетия', 'Ханты-Мансийский АО', 'Волгоградская область', 'Алтайский край', 'Бурятия', 'Омская область', 'Санкт-Петербург', 'Башкирия', 'Камчатская область', 'Свердловская область', 'Калужская область', 'Самарская область', 'Тульская область', 'Тверская область', 'Новгородская область', 'Дагестан', 'Амурская область', 'Ульяновская область', 'Агинский Бурятский АО', 'Вологодская область', 'Карачаево-Черкесия', 'Ямало-Ненецкий АО', 'Кемеровская область', 'Челябинская область', 'Ставропольский край', 'Хабаровский край', 'Мурманская область', 'Липецкая область', 'Саратовская область', 'Адыгея', 'Ивановская область', 'Читинская область', 'Пензенская область', 'Татарстан', 'Карелия', 'Московская область', 'Рязанская область', 'Марийская республика', 'Красноярский край', 'Орловская область', 'Пермская область', 'Еврейская АО', 'Оренбургская область', 'Коми', 'Белгородская область', 'Кировская область', 'Смоленская область', 'Усть-Ордынский Бурятский АО', 'Тамбовская область', 'Курская область', 'Брянская область', 'Калмыкия', 'Иркутская область', 'Тюменская область', 'Горный Алтай', 'Магаданская область', 'Костромская область', 'Чувашия', 'Приморский край', 'Кабардино-Балкария', 'Курганская область', 'Краснодарский край', 'Калининградская область', 'Эвенкийский АО', 'Мордовская республика'}
#
# TP_PROVINCE
# {nan, 'Владимирская область', 'Москва', 'Воронежская область', 'Ярославская область', 'Архангельская область', 'Томская область', 'Нижегородская область', 'Удмуртия', 'Сахалинская область', 'Новосибирская область', 'Ростовская область', 'Псковская область', 'Якутия', 'Астраханская область', 'Ханты-Мансийский АО', 'Волгоградская область', 'Алтайский край', 'Бурятия', 'Санкт-Петербург', 'Омская область', 'Башкирия', 'Камчатская область', 'Свердловская область', 'Калужская область', 'Самарская область', 'Тульская область', 'Тверская область', 'Новгородская область', 'Амурская область', 'Ульяновская область', 'Вологодская область', 'Кемеровская область', 'Челябинская область', 'Ставропольский край', 'Хабаровский край', 'Мурманская область', 'Липецкая область', 'Саратовская область', 'Адыгея', 'Ивановская область', 'Читинская область', 'Пензенская область', 'Татарстан', 'Карелия', 'Рязанская область', 'Марийская республика', 'Красноярский край', 'Орловская область', 'Пермская область', 'Еврейская АО', 'Оренбургская область', 'Коми', 'Белгородская область', 'Кировская область', 'Смоленская область', 'Тамбовская область', 'Курская область', 'Брянская область', 'Иркутская область', 'Тюменская область', 'Горный Алтай', 'Магаданская область', 'Костромская область', 'Чувашия', 'Приморский край', 'Курганская область', 'Калининградская область', 'Краснодарский край', 'Кабардино-Балкария', 'Мордовская республика'}
,13', '3770', '3800', '1063,17', '2490', '3410', '664,94', '2957,71', '1909,16', '840', '760,65', '1429,99', '3090', '2570', '1070,52', '794,5', '2510', '3099,42', '4690', '879,74', '2858,62', '957,59', '3202,2', '1347,12', '749,05', '1940', '2779,4', '1243,83', '1221,92', '1181,13', '1840', '2429,5', '1672,88', '2094,3', '446,31', '1023,66', '2064,08', '2695,38', '5550', '1338,69', '2940', '2168,26', '3011,18', '502,2', '4200', '552,57', '1650,53', '716,44', '3339,71', '1716,52', '2712,72', '1839,85', '367,35', '846,74', '4100', '1120,93', '3702,8', '1740,19', '1336,38', '879', '1820', '2132,88', '4956,4', '757,75', '1268', '4893,17', '805,73', '3501,45', '2830', '770', '1832,91', '4960', '997,89', '3110', '1198,15', '3550', '1658,42', '1896,34', '2176,36', '1953,6', '5470', '3033,41', '1175,57', '1094,85', '1892,28', '3690', '668,53', '590', '2850', '821,93', '1509,44', '1292,59', '2960', '697,72', '880,74', '4560', '2352,78', '1375,39', '4055,03', '921,58', '2800', '1506,39', '1959,42', '695,06', '1077,03', '11460', '660', '801,8', '1649,37', '1017,28', '3170', '2618,78', '6500', '1817,57', '682', '918,83', '4250', '736,3', '580', '684,89', '1374,28', '3355,19', '871,07', '2979,35', '1287,35', '1549', '6532,49', '3360', '1160', '3820', '2300', '605,32', '966,53', '4758,14', '91,27', '3040', '1069,6', '666,41', '3440', '4050', '1851,55', '1098,1', '1980', '1999,73', '1562,12', '818,74', '2289,89', '1142,83', '3299,1', '1 ...

# %%
# можно заметить что некоторые переменные, 
# которые обозначены как строки (например PERSONAL_INCOME) на самом деле числа,
# но по какой-то (ниже увидим) причине были распознаны как строки

# %%
all_data['PERSONAL_INCOME'] = all_data['PERSONAL_INCOME'].map(lambda x: x.replace(',', '.')).astype('float')

# %%
# причина же что использовалась запятая для разделения не целой части числа

# %%
all_data['CREDIT'] = all_data['CREDIT'].map(lambda x: x.replace(',', '.')).astype('float')
all_data['FST_PAYMENT'] = all_data['FST_PAYMENT'].map(lambda x: x.replace(',', '.')).astype('float')
all_data['LOAN_AVG_DLQ_AMT'] = all_data['LOAN_AVG_DLQ_AMT'].map(lambda x: x.replace(',', '.')).astype('float')
all_data['LOAN_MAX_DLQ_AMT'] = all_data['LOAN_MAX_DLQ_AMT'].map(lambda x: x.replace(',', '.')).astype('float')

# %%
# запускаем повторно код и смотрим, какие столбцы с какими строковыми значениями остались

# %%
for i in all_data.columns:
    if str(all_data[i].dtype) == 'object':
        print(i)
        print(set(all_data[i]))
        print()
# Out:
# EDUCATION
# {'Ученая степень', 'Неполное среднее', 'Неоконченное высшее', 'Высшее', 'Среднее специальное', 'Два и более высших образования', 'Среднее'}
#
# MARITAL_STATUS
# {'Не состоял в браке', 'Состою в браке', 'Гражданский брак', 'Разведен(а)', 'Вдовец/Вдова'}
#
# GEN_INDUSTRY
# {nan, 'Сельское хозяйство', 'Туризм', 'Государственная служба', 'Энергетика', 'Нефтегазовая промышленность', 'Юридические услуги/нотариальные услуги', 'Маркетинг', 'Недвижимость', 'Строительство', 'Коммунальное хоз-во/Дорожные службы', 'Металлургия/Промышленность/Машиностроение', 'Химия/Парфюмерия/Фармацевтика', 'Страхование', 'Информационные технологии', 'Ресторанный бизнес/Общественное питание', 'Управляющая компания', 'Логистика', 'СМИ/Реклама/PR-агенства', 'Подбор персонала', 'ЧОП/Детективная д-ть', 'Образование', 'Торговля', 'Здравоохранение', 'Наука', 'Банк/Финансы', 'Салоны красоты и здоровья', 'Сборочные производства', 'Развлечения/Искусство', 'Другие сферы', 'Информационные услуги', 'Транспорт'}
#
# GEN_TITLE
# {'Руководитель высшего звена', nan, 'Индивидуальный предприниматель', 'Рабочий', 'Специалист', 'Высококвалифиц. специалист', 'Руководитель низшего звена', 'Служащий', 'Работник сферы услуг', 'Военнослужащий по контракту', 'Руководитель среднего звена', 'Другое', 'Партнер'}
#
# ORG_TP_STATE
# {nan, 'Некоммерческая организация', 'Индивидуальный предприниматель', 'Частная компания', 'Государственная комп./учреж.', 'Частная ком. с инос. капиталом'}
#
# ORG_TP_FCAPITAL
# {nan, 'Без участия', 'С участием'}
#
# JOB_DIR
# {nan, 'Снабжение и сбыт', 'Служба безопасности', 'Вспомогательный техперсонал', 'Пр-техн. обесп. и телеком.', 'Участие в основ. деятельности', 'Реклама и маркетинг', 'Адм-хоз. и трансп. службы', 'Юридическая служба', 'Кадровая служба и секретариат', 'Бухгалтерия, финансы, планир.'}
#
# FAMILY_INCOME
# {'от 10000 до 20000 руб.', 'от 5000 до 10000 руб.', 'от 20000 до 50000 руб.', 'до 5000 руб.', 'свыше 50000 руб.'}
#
# PERSONAL_INCOME
# {'5450', '2500', '32500', '23500', '5460', '5582', '15300', '25500', '16107,47', '9400', '19000', '75000', '17400', '10300', '67000', '68000', '130000', '14200', '14700', '52000', '5790', '19600', '23100', '4887', '15750', '15400', '8750', '8250', '42000', '8060', '6825', '6780', '12800', '4550', '16900', '50000', '9700', '6670', '21800', '19800', '80000', '24800', '5966', '7850', '6270', '22955', '48000', '4340', '7500', '13300', '16200', '11500', '35000', '11200', '6350', '60000', '12900', '22180', '12200', '18700', '4530', '4700', '10200', '5380', '10000', '6800', '12500', '4000', '32640', '5400', '11640', '5600', '4850', '10100', '53500', '8600', '3900', '4704', '13000', '54000', '7101', '4860', '9240', '4600', '5300', '12700', '25000', '6100', '70000', '10800', '3000', '41900', '29400', '26500', '8300', '26800', '27200', '9000', '55000', '19500', '158000', '18000', '9628', '7300', '10400', '5700', '17700', '200000', '94000', '8726', '41000', '6400', '7800', '18300', '9750', '13500', '20880', '23000', '11600', '43000', '6524', '5750', '13000000', '160000', '12000', '10600', '15560', '24500', '42500', '9640', '18500', '7050', '7640', '13650', '110000', '9330', '13160', '13600', '8000', '5425', '10700', '6700', '19300', '5120', '2776', '46000', '170000', '7830', '7400', '6900', '8700', '15700', '53000', '3400', '3500', '44000', '7900', '4400', '7000', '9340', '11800', '9900', '11300', '8066', '120000', '20500', '17800', '8800', '17900', '19200', '10500', '14600', '51000', '5173', '6180', '16800', '15800', '5800', '12400', '9300', '15200', '4480', '21500', '9600', '14120', '7251', '58640', '9200', '9100', '12100', '5360', '18100', '5350', '8500', '6200', '14000', '4330', '8350', '5000', '4300', '13150', '7100', '24400', '17600', '2680', '12650', '14300', '20600', '47000', '18200', '15600', '8400', '230000', '26000', '6650', '17500', '5280', '34500', '7600', '17404', '15939', '25800', '7250', '12450', '6359', '7330', '3800', '16500', '9500', '13700', '5230', '29000', '45900', '13400', '15000', '37000', '7082', '11900', '10900', '29500', '7460', '15380', '16050', '5200', '22565', '7340', '42145', '18800', '7550', '29800', '8900', '45000', '150000', '6608', '28470', '33000', '6600', '17300', '17000', '40000', '4200', '5050', '92000', '7350', '3600', '5500', '19700', '23800', '2100', '17200', '21000', '4100', '5339', '49000', '14900', '4360', '57000', '11700', '21300', '220000', '1950', '20646,16', '11400', '7220', '4750', '22000', '6300', '8030', '11000', '18600', '22120', '7700', '67700', '5088', '5085', '250000', '12300', '5446', '13200', '9860', '20000', '27300', '15500', '16300', '14500', '3300', '4515', '2800', '7170,08', '6299,19', '32000', '22500', '36000', '5100', '56000', '6000', '4680', '7380', '6500', '3700', '13100', '4250', '4760', '18250', '16100', '13900', '16700', '4900', '7200', '8100', '7780', '35500', '39000', '5890', '7260', '4500', '3100', '2000', '30600', '5680', '28000', '12600', '24000', '30000', '2300', '34000', '16000', '77000', '9800', '31000', '7650', '38600', '8075', '14800', '5900', '28300', '38000', '100000', '13450', '3200', '16600', '24', '5860', '4590', '15900', '4800', '13800', '14358', '8200', '4950', '27000', '90000', '65000'}
#
# REG_ADDRESS_PROVINCE
# {'Ленинградская область', 'Владимирская область', 'Москва', 'Воронежская область', 'Ярославская область', 'Архангельская область', 'Томская область', 'Нижегородская область', 'Удмуртия', 'Сахалинская область', 'Хакасия', 'Новосибирская область', 'Ростовская область', 'Коми-Пермяцкий АО', 'Псковская область', 'Якутия', 'Астраханская область', 'Северная Осетия', 'Ханты-Мансийский АО', 'Волгоградская область', 'Алтайский край', 'Бурятия', 'Омская область', 'Санкт-Петербург', 'Башкирия', 'Камчатская область', 'Свердловская область', 'Калужская область', 'Самарская область', 'Тульская область', 'Тверская область', 'Новгородская область', 'Дагестан', 'Амурская область', 'Ульяновская область', 'Агинский Бурятский АО', 'Вологодская область', 'Карачаево-Черкесия', 'Ямало-Ненецкий АО', 'Кемеровская область', 'Челябинская область', 'Ставропольский край', 'Хабаровский край', 'Мурманская область', 'Липецкая область', 'Саратовская область', 'Адыгея', 'Ивановская область', 'Читинская область', 'Пензенская область', 'Татарстан', 'Карелия', 'Рязанская область', 'Московская область', 'Марийская республика', 'Красноярский край', 'Орловская область', 'Пермская область', 'Еврейская АО', 'Оренбургская область', 'Коми', 'Белгородская область', 'Кировская область', 'Смоленская область', 'Усть-Ордынский Бурятский АО', 'Тамбовская область', 'Курская область', 'Брянская область', 'Калмыкия', 'Иркутская область', 'Тюменская область', 'Горный Алтай', 'Магаданская область', 'Костромская область', 'Чувашия', 'Приморский край', 'Кабардино-Балкария', 'Курганская область', 'Краснодарский край', 'Калининградская область', 'Эвенкийский АО', 'Мордовская республика'}
#
# FACT_ADDRESS_PROVINCE
# {'Ленинградская область', 'Владимирская область', 'Москва', 'Воронежская область', 'Ярославская область', 'Архангельская область', 'Томская область', 'Нижегородская область', 'Удмуртия', 'Сахалинская область', 'Хакасия', 'Новосибирская область', 'Ростовская область', 'Коми-Пермяцкий АО', 'Псковская область', 'Якутия', 'Астраханская область', 'Северная Осетия', 'Ханты-Мансийский АО', 'Волгоградская область', 'Алтайский край', 'Бурятия', 'Омская область', 'Санкт-Петербург', 'Башкирия', 'Камчатская область', 'Свердловская область', 'Калужская область', 'Самарская область', 'Тульская область', 'Тверская область', 'Новгородская область', 'Дагестан', 'Амурская область', 'Ульяновская область', 'Агинский Бурятский АО', 'Вологодская область', 'Карачаево-Черкесия', 'Ямало-Ненецкий АО', 'Кемеровская область', 'Челябинская область', 'Ставропольский край', 'Хабаровский край', 'Мурманская область', 'Липецкая область', 'Саратовская область', 'Адыгея', 'Ивановская область', 'Читинская область', 'Пензенская область', 'Татарстан', 'Карелия', 'Московская область', 'Рязанская область', 'Марийская республика', 'Чечня', 'Красноярский край', 'Орловская область', 'Пермская область', 'Еврейская АО', 'Оренбургская область', 'Коми', 'Белгородская область', 'Кировская область', 'Смоленская область', 'Усть-Ордынский Бурятский АО', 'Тамбовская область', 'Курская область', 'Брянская область', 'Калмыкия', 'Иркутская область', 'Тюменская область', 'Горный Алтай', 'Магаданская область', 'Костромская область', 'Чувашия', 'Приморский край', 'Кабардино-Балкария', 'Курганская область', 'Краснодарский край', 'Калининградская область', 'Эвенкийский АО', 'Мордовская республика'}
#
# POSTAL_ADDRESS_PROVINCE
# {'Ленинградская область', 'Владимирская область', 'Москва', 'Воронежская область', 'Ярославская область', 'Архангельская область', 'Томская область', 'Нижегородская область', 'Удмуртия', 'Сахалинская область', 'Хакасия', 'Новосибирская область', 'Ростовская область', 'Коми-Пермяцкий АО', 'Псковская область', 'Якутия', 'Астраханская область', 'Северная Осетия', 'Ханты-Мансийский АО', 'Волгоградская область', 'Алтайский край', 'Бурятия', 'Омская область', 'Санкт-Петербург', 'Башкирия', 'Камчатская область', 'Свердловская область', 'Калужская область', 'Самарская область', 'Тульская область', 'Тверская область', 'Новгородская область', 'Дагестан', 'Амурская область', 'Ульяновская область', 'Агинский Бурятский АО', 'Вологодская область', 'Карачаево-Черкесия', 'Ямало-Ненецкий АО', 'Кемеровская область', 'Челябинская область', 'Ставропольский край', 'Хабаровский край', 'Мурманская область', 'Липецкая область', 'Саратовская область', 'Адыгея', 'Ивановская область', 'Читинская область', 'Пензенская область', 'Татарстан', 'Карелия', 'Московская область', 'Рязанская область', 'Марийская республика', 'Красноярский край', 'Орловская область', 'Пермская область', 'Еврейская АО', 'Оренбургская область', 'Коми', 'Белгородская область', 'Кировская область', 'Смоленская область', 'Усть-Ордынский Бурятский АО', 'Тамбовская область', 'Курская область', 'Брянская область', 'Калмыкия', 'Иркутская область', 'Тюменская область', 'Горный Алтай', 'Магаданская область', 'Костромская область', 'Чувашия', 'Приморский край', 'Кабардино-Балкария', 'Курганская область', 'Краснодарский край', 'Калининградская область', 'Эвенкийский АО', 'Мордовская республика'}
#
# TP_PROVINCE
# {nan, 'Владимирская область', 'Москва', 'Воронежская область', 'Ярославская область', 'Архангельская область', 'Томская область', 'Нижегородская область', 'Удмуртия', 'Сахалинская область', 'Новосибирская область', 'Ростовская область', 'Псковская область', 'Якутия', 'Астраханская область', 'Ханты-Мансийский АО', 'Волгоградская область', 'Алтайский край', 'Бурятия', 'Санкт-Петербург', 'Омская область', 'Башкирия', 'Камчатская область', 'Свердловская область', 'Калужская область', 'Самарская область', 'Тульская область', 'Тверская область', 'Новгородская область', 'Амурская область', 'Ульяновская область', 'Вологодская область', 'Кемеровская область', 'Челябинская область', 'Ставропольский край', 'Хабаровский край', 'Мурманская область', 'Липецкая область', 'Саратовская область', 'Адыгея', 'Ивановская область', 'Читинская область', 'Пензенская область', 'Татарстан', 'Карелия', 'Рязанская область', 'Марийская республика', 'Красноярский край', 'Орловская область', 'Пермская область', 'Еврейская АО', 'Оренбургская область', 'Коми', 'Белгородская область', 'Кировская область', 'Смоленская область', 'Тамбовская область', 'Курская область', 'Брянская область', 'Иркутская область', 'Тюменская область', 'Горный Алтай', 'Магаданская область', 'Костромская область', 'Чувашия', 'Приморский край', 'Курганская область', 'Калининградская область', 'Краснодарский край', 'Кабардино-Балкария', 'Мордовская республика'}
#
# REGION_NM
# {nan, 'ЦЕНТРАЛЬНЫЙ 2', 'ЦЕНТРАЛЬНЫЙ ОФИС', 'ВОСТОЧНО-СИБИРСКИЙ', 'ЗАПАДНО-СИБИРСКИЙ', 'СЕВЕРО-ЗАПАДНЫЙ', 'ДАЛЬНЕВОСТОЧНЫЙ', 'ЮЖНЫЙ', 'УРАЛЬСКИЙ', 'ПОВОЛЖСКИЙ', 'ПРИВОЛЖСКИЙ', 'ЦЕНТРАЛЬНЫЙ 1'}

# %% [markdown]
# # Данные готовы, теперь вам предлагается начать решать задачу

# %%
# Есть ли пропуски в данных? что с ними сделать?

# Ваш код :-)

# %%
# Как поступить со строковыми переменными?

# Ваш код :-)

# %%
# В итоге должны получиться данные без пропусков и только числовые

# %%
# Вновь разделите на train и test (не мешая)

# Ваш код :-)

# %%
# Сделать hold-out sampling на train выборке
from sklearn.cross_validation import train_test_split

# test_size=0.3, random_state=42

# Ваш код :-)

# %%
# Попробовать следующие "черные ящики": интерфейс одинаковый 
#     fit, 
#     predict, 
#     predict_proba

from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression

# Ваш код :-)

# %%
# Посчитать метрики стандартные
# accuracy, precision, recall

# Ваш код :-)

# %%
# Визуалищировать эти метрики всех моделей на одном графике (чтоб визуально посмотреть)

# Ваш код :-)

# %%
# Потроить roc-кривые всех можелей на одном графике
# Вывести roc_auc каждой моделе

# Ваш код :-)

# %%
from sklearn.cross_validation import cross_val_score
# Сделать k-fold (10 фолдов) кросс-валидацию каждой модели
# И посчитать средний roc_auc

# Ваш код :-)

# %%
# Взять лучшую модель и сделать predict (с вероятностями (!!!)) для test выборки

# Ваш код :-)
